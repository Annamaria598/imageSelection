# %%
from ImageSelection.classificazione_knn import image_to_data

# %%
features = image_to_data("ImageSelection/img/pelle3.PNG")

# %%
import matplotlib.pyplot as plt

# %%
from skimage.color import lab2rgb

# %%
plt.imshow(lab2rgb(features["img"]))

# %%
plt.imshow(features["L"], cmap="gray")

# %%
plt.imshow(features["a"], cmap="gray")

# %%
plt.imshow(features["b"], cmap="gray")

# %%
plt.imshow(features["L_mf"], cmap="gray")

# %%
plt.imshow(features["a_mf"], cmap="gray")

# %%
plt.imshow(features["b_mf"], cmap="gray")

# %%
plt.imshow(features["L_edge"], cmap="gray")

# %%
plt.imshow(features["a_edge"], cmap="gray")

# %%
plt.imshow(features["b_edge"], cmap="gray")

# %%
m = np.array([
    []
    
])
